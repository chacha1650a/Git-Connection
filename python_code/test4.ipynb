# %%
import requests

url = "http://localhost:5678/webhook-test/cb29a92e-6726-4e5d-b726-8dafa4730e30"
payload = {"ip": "1.2.3.4", "level": 10, "rule": "5712"}
r = requests.post(url, json=payload)
print(r.status_code)   # 200
# Out:
# 200
