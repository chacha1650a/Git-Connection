# %%
values = [1, 2, 3, 4]
count = 0

for value in values:
    print(value)
    count += 1

print(len(str(values)), "개 감지")
if (count == 4) :
    values.append(5)

print(values)
# Out:
# 1
# 2
# 3
# 4
# 1 개 감지
# [1, 2, 3, 4, 5]
